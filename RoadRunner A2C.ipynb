# %%
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack, VecTransposeImage
import pandas as pd
import gymnasium as gym
import ale_py
import matplotlib.pyplot as plt
import numpy as np
import base64
import cv2
import torch
import os
import torch.nn.functional as F
import math
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import shap
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.distance import cdist
import pickle
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.callbacks import EvalCallback

from sympy import latex
from IPython.display import display, Math

import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split

from sklearn.preprocessing import StandardScaler

np.math = math
gym.register_envs(ale_py)

# %% [markdown]
# # Cuda

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Establish Atari Enviornment

# %%
def make_RoadRunner_env():
  env = gym.make("RoadRunnerNoFrameskip-v4")
  env = AtariWrapper(env)
  return env

# %% [markdown]
# # Construct CNN-based Feature Extractors

# %%
class NatureCNN(BaseFeaturesExtractor):
    """
    Nature CNN feature extractor as in Mnih et al. (2015), used in SB3’s CnnPolicy/QNetwork.
    输出 feature vector 维度为 16

    :param observation_space: (gym.Space) 图像观测空间，形状 (C, H, W)
    :param features_dim: (int) 最后输出的特征维度，默认 16
    """
    def __init__(self, observation_space, features_dim: int = 16):
        super().__init__(observation_space, features_dim)

        # print(observation_space.shape)

        # 输入通道数 C
        n_input_channels = observation_space.shape[0]

        # print(n_input_channels)

        # 卷积 + ReLU + Flatten
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(start_dim=1)
        )

        # figure out size of the flattened CNN output
        with torch.no_grad():
            # 1) sample(): numpy ndarray, shape = (C, H, W)
            obs = observation_space.sample()
            # 2) 加 batch 维：(1, C, H, W)
            obs_tensor = torch.as_tensor(obs)[None].float()
            # 3) 获取压缩后的特征
            n_flatten = self.cnn(obs_tensor).shape[1]

            # print(n_flatten)

        # 三层全连接
        self.linear = nn.Sequential(
            nn.Linear(n_flatten, 512),
            nn.ReLU(),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Linear(128, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        # observations: [batch, C, H, W]
        x = self.cnn(observations)
        return self.linear(x)

# %% [markdown]
# # A2C

# %%
from stable_baselines3 import A2C

# %%
n_envs = 16
RoadRunner_env = DummyVecEnv([make_RoadRunner_env for _ in range(n_envs)])  # 用DummyVecEnv包装环境，使其并行
RoadRunner_env = VecTransposeImage(RoadRunner_env) # 转换成 (C, H, W) 而不是 (H, W, C)
RoadRunner_env = VecFrameStack(RoadRunner_env, n_stack=4)  # 堆叠帧，4帧堆叠

# %%
RoadRunner_env.observation_space.shape
# Out:
# (4, 84, 84)

# %% [markdown]
# # Establish A2C

# %%
policy_kwargs = dict(
    features_extractor_class=NatureCNN,
    features_extractor_kwargs=dict(features_dim=16),
    optimizer_class=RMSpropTFLike,
    optimizer_kwargs=dict(eps=1e-5)
)

n_timesteps = 10000000.0
ent_coef = 0.01
vf_coef = 0.25

A2C_model = A2C(
    policy="CnnPolicy",
    env=RoadRunner_env,
    policy_kwargs=policy_kwargs,
    verbose=1,
    ent_coef=ent_coef,
    vf_coef=vf_coef,
    tensorboard_log="./RoadRunner/a2c"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 policy_kwargs = dict(
#       2     features_extractor_class=NatureCNN,
#       3     features_extractor_kwargs=dict(features_dim=16),
# ----> 4     optimizer_class=RMSpropTFLike,
#       5     optimizer_kwargs=dict(eps=1e-5)
#       6 )
#       8 n_timesteps = 10000000.0
#       9 ent_coef = 0.01
#
# NameError: name 'RMSpropTFLike' is not defined

# %%
A2C_model.policy # 查看 A2C 算法模型架构
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 A2C_model.policy # 查看 A2C 算法模型架构
#
# NameError: name 'A2C_model' is not defined

# %% [markdown]
# # Train A2C

# %%
eval_callback = EvalCallback(
    RoadRunner_env,
    best_model_save_path="./RoadRunner/a2c",
    log_path="./RoadRunner/a2c",   # tensorboard 或者 .csv 会写到这里
    eval_freq=100000,    # 每 10k 步评估一次
    n_eval_episodes=10,   # 每次评估跑 10 条完整 episode
    deterministic=True,   # 用确定性策略评估
    render=False,
)

A2C_model.learn(total_timesteps=int(n_timesteps), callback=eval_callback)

# 训练完成后保存模型
A2C_model.save("./RoadRunner/a2c")
# Out:
# Logging to ./RoadRunner/a2c\A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 474      |
# |    iterations         | 100      |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -8.97    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0749   |
# |    value_loss         | 0.00329  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 491      |
# |    iterations         | 200      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0906   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0429   |
# |    value_loss         | 0.00105  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 526      |
# |    iterations         | 300      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.492    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0339  |
# |    value_loss         | 0.000917 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 400      |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.156    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00626  |
# |    value_loss         | 0.000762 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 563      |
# |    iterations         | 500      |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0839   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.0153   |
# |    value_loss         | 0.000635 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 585      |
# |    iterations         | 600      |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -0.42    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0229   |
# |    value_loss         | 0.00132  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 602      |
# |    iterations         | 700      |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -0.775   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.00501  |
# |    value_loss         | 0.000379 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 800      |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.642    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.00679 |
# |    value_loss         | 0.000215 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 627      |
# |    iterations         | 900      |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0323   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.00475 |
# |    value_loss         | 0.000378 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 636      |
# |    iterations         | 1000     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0336   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.014   |
# |    value_loss         | 0.000799 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 641      |
# |    iterations         | 1100     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0734   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.00228  |
# |    value_loss         | 0.000167 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 644      |
# |    iterations         | 1200     |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.163    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0155  |
# |    value_loss         | 0.000107 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 646      |
# |    iterations         | 1300     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0343   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0494  |
# |    value_loss         | 0.00132  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 648      |
# |    iterations         | 1400     |
# |    time_elapsed       | 172      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.469    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.00538 |
# |    value_loss         | 2.72e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 653      |
# |    iterations         | 1500     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -0.118   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00323  |
# |    value_loss         | 4.2e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 655       |
# |    iterations         | 1600      |
# |    time_elapsed       | 195       |
# |    total_timesteps    | 128000    |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0.283     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -0.000784 |
# |    value_loss         | 3.24e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 658      |
# |    iterations         | 1700     |
# |    time_elapsed       | 206      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.446    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -3.1e-05 |
# |    value_loss         | 2.87e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 657      |
# |    iterations         | 1800     |
# |    time_elapsed       | 218      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.638    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.000261 |
# |    value_loss         | 2.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 659      |
# |    iterations         | 1900     |
# |    time_elapsed       | 230      |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.586    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.000444 |
# |    value_loss         | 3.49e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 661      |
# |    iterations         | 2000     |
# |    time_elapsed       | 241      |
# |    total_timesteps    | 160000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.575    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0011  |
# |    value_loss         | 2.15e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 662      |
# |    iterations         | 2100     |
# |    time_elapsed       | 253      |
# |    total_timesteps    | 168000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.242    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.011   |
# |    value_loss         | 9.86e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 663      |
# |    iterations         | 2200     |
# |    time_elapsed       | 265      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.615    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.00086  |
# |    value_loss         | 2.73e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 664      |
# |    iterations         | 2300     |
# |    time_elapsed       | 276      |
# |    total_timesteps    | 184000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00457 |
# |    value_loss         | 1.77e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 664      |
# |    iterations         | 2400     |
# |    time_elapsed       | 289      |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.18     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.00353 |
# |    value_loss         | 7.25e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 665      |
# |    iterations         | 2500     |
# |    time_elapsed       | 300      |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.00503 |
# |    value_loss         | 1.1e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 666      |
# |    iterations         | 2600     |
# |    time_elapsed       | 311      |
# |    total_timesteps    | 208000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.771    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.00115 |
# |    value_loss         | 2.92e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 667      |
# |    iterations         | 2700     |
# |    time_elapsed       | 323      |
# |    total_timesteps    | 216000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.682    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.00416 |
# |    value_loss         | 1.77e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 669      |
# |    iterations         | 2800     |
# |    time_elapsed       | 334      |
# |    total_timesteps    | 224000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.8      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0019  |
# |    value_loss         | 7.15e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 2900     |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 232000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.474    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.00473 |
# |    value_loss         | 9.14e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 670      |
# |    iterations         | 3000     |
# |    time_elapsed       | 357      |
# |    total_timesteps    | 240000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.351    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.00959 |
# |    value_loss         | 0.000145 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 671      |
# |    iterations         | 3100     |
# |    time_elapsed       | 369      |
# |    total_timesteps    | 248000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.558    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0122  |
# |    value_loss         | 0.000114 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 672      |
# |    iterations         | 3200     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 256000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.303    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0171  |
# |    value_loss         | 0.000332 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 3300     |
# |    time_elapsed       | 391      |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.401    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00133  |
# |    value_loss         | 3.41e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 3400     |
# |    time_elapsed       | 403      |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0276   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0508   |
# |    value_loss         | 0.0253   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 3500     |
# |    time_elapsed       | 414      |
# |    total_timesteps    | 280000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.855    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.00247 |
# |    value_loss         | 2.01e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 3600     |
# |    time_elapsed       | 425      |
# |    total_timesteps    | 288000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.67     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 6.47e-05 |
# |    value_loss         | 1.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 3700     |
# |    time_elapsed       | 438      |
# |    total_timesteps    | 296000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.509    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00418  |
# |    value_loss         | 2.42e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 3800     |
# |    time_elapsed       | 451      |
# |    total_timesteps    | 304000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.78     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.00183 |
# |    value_loss         | 3.06e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 671      |
# |    iterations         | 3900     |
# |    time_elapsed       | 464      |
# |    total_timesteps    | 312000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.833    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.000659 |
# |    value_loss         | 7.5e-06  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 671      |
# |    iterations         | 4000     |
# |    time_elapsed       | 476      |
# |    total_timesteps    | 320000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.695    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00224 |
# |    value_loss         | 2.42e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 671      |
# |    iterations         | 4100     |
# |    time_elapsed       | 488      |
# |    total_timesteps    | 328000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.788    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.000281 |
# |    value_loss         | 3.04e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 672      |
# |    iterations         | 4200     |
# |    time_elapsed       | 499      |
# |    total_timesteps    | 336000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.755    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.00157 |
# |    value_loss         | 2.67e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 4300     |
# |    time_elapsed       | 510      |
# |    total_timesteps    | 344000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.782    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.00353 |
# |    value_loss         | 2.45e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 4400     |
# |    time_elapsed       | 522      |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.453    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0105  |
# |    value_loss         | 0.000104 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 4500     |
# |    time_elapsed       | 533      |
# |    total_timesteps    | 360000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.357    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0214  |
# |    value_loss         | 0.00035  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 4600     |
# |    time_elapsed       | 545      |
# |    total_timesteps    | 368000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0236   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.165    |
# |    value_loss         | 0.0597   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 4700     |
# |    time_elapsed       | 557      |
# |    total_timesteps    | 376000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.356    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.000289 |
# |    value_loss         | 3.95e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 4800     |
# |    time_elapsed       | 569      |
# |    total_timesteps    | 384000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.289    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.00545 |
# |    value_loss         | 2.36e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 4900     |
# |    time_elapsed       | 581      |
# |    total_timesteps    | 392000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.652    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.00717 |
# |    value_loss         | 9.15e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 5000     |
# |    time_elapsed       | 593      |
# |    total_timesteps    | 400000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.689    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.008   |
# |    value_loss         | 8.34e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 673      |
# |    iterations         | 5100     |
# |    time_elapsed       | 605      |
# |    total_timesteps    | 408000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.464    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0234  |
# |    value_loss         | 0.000314 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 5200     |
# |    time_elapsed       | 616      |
# |    total_timesteps    | 416000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.167    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0224  |
# |    value_loss         | 0.000319 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 5300     |
# |    time_elapsed       | 628      |
# |    total_timesteps    | 424000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.715    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.00949 |
# |    value_loss         | 0.000153 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 5400     |
# |    time_elapsed       | 639      |
# |    total_timesteps    | 432000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.746    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.00884 |
# |    value_loss         | 6.29e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 5500     |
# |    time_elapsed       | 651      |
# |    total_timesteps    | 440000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.745    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00615 |
# |    value_loss         | 3.26e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 5600     |
# |    time_elapsed       | 662      |
# |    total_timesteps    | 448000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0985   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.139    |
# |    value_loss         | 0.0471   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 5700     |
# |    time_elapsed       | 674      |
# |    total_timesteps    | 456000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.865    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00693 |
# |    value_loss         | 0.000102 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 5800     |
# |    time_elapsed       | 685      |
# |    total_timesteps    | 464000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.772    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.00238  |
# |    value_loss         | 5.24e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 5900     |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 472000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0552   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0107  |
# |    value_loss         | 9.79e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 6000     |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -0.0753  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.00532 |
# |    value_loss         | 3.21e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 6100     |
# |    time_elapsed       | 720      |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.717    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 0.00126  |
# |    value_loss         | 2.29e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 6200     |
# |    time_elapsed       | 731      |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.538    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.00957 |
# |    value_loss         | 5.19e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 6300     |
# |    time_elapsed       | 743      |
# |    total_timesteps    | 504000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | -0.474   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.011   |
# |    value_loss         | 0.000125 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 6400     |
# |    time_elapsed       | 756      |
# |    total_timesteps    | 512000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.744    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.00548  |
# |    value_loss         | 4.45e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 6500     |
# |    time_elapsed       | 768      |
# |    total_timesteps    | 520000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.888    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00269 |
# |    value_loss         | 2.8e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 6600     |
# |    time_elapsed       | 779      |
# |    total_timesteps    | 528000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.716    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.00172 |
# |    value_loss         | 7.8e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 677      |
# |    iterations         | 6700     |
# |    time_elapsed       | 791      |
# |    total_timesteps    | 536000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.775    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.00889 |
# |    value_loss         | 6.1e-05  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 6800     |
# |    time_elapsed       | 805      |
# |    total_timesteps    | 544000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.816    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00504 |
# |    value_loss         | 2.94e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 675       |
# |    iterations         | 6900      |
# |    time_elapsed       | 817       |
# |    total_timesteps    | 552000    |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0.77      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -0.000558 |
# |    value_loss         | 3.35e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 7000     |
# |    time_elapsed       | 828      |
# |    total_timesteps    | 560000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.823    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00693 |
# |    value_loss         | 9.03e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 7100     |
# |    time_elapsed       | 840      |
# |    total_timesteps    | 568000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.822    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.00444 |
# |    value_loss         | 0.000118 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 7200     |
# |    time_elapsed       | 853      |
# |    total_timesteps    | 576000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.292    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.0217  |
# |    value_loss         | 0.000679 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 7300     |
# |    time_elapsed       | 864      |
# |    total_timesteps    | 584000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.00245 |
# |    value_loss         | 4.88e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 7400     |
# |    time_elapsed       | 877      |
# |    total_timesteps    | 592000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.514    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.0166  |
# |    value_loss         | 0.000368 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 7500     |
# |    time_elapsed       | 889      |
# |    total_timesteps    | 600000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.815    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | 0.0055   |
# |    value_loss         | 5.01e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 7600     |
# |    time_elapsed       | 900      |
# |    total_timesteps    | 608000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.801    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | 0.00107  |
# |    value_loss         | 4.64e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 7700     |
# |    time_elapsed       | 912      |
# |    total_timesteps    | 616000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7699     |
# |    policy_loss        | 0.000118 |
# |    value_loss         | 2.34e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 674      |
# |    iterations         | 7800     |
# |    time_elapsed       | 924      |
# |    total_timesteps    | 624000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.717    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.00691 |
# |    value_loss         | 0.000123 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 7900     |
# |    time_elapsed       | 936      |
# |    total_timesteps    | 632000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.827    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7899     |
# |    policy_loss        | 0.000943 |
# |    value_loss         | 4.79e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8000     |
# |    time_elapsed       | 948      |
# |    total_timesteps    | 640000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.806    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7999     |
# |    policy_loss        | -0.0113  |
# |    value_loss         | 9.47e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8100     |
# |    time_elapsed       | 959      |
# |    total_timesteps    | 648000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8099     |
# |    policy_loss        | -0.00435 |
# |    value_loss         | 0.000124 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8200     |
# |    time_elapsed       | 971      |
# |    total_timesteps    | 656000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.814    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8199     |
# |    policy_loss        | -0.0063  |
# |    value_loss         | 5.39e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8300     |
# |    time_elapsed       | 983      |
# |    total_timesteps    | 664000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.872    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8299     |
# |    policy_loss        | -0.008   |
# |    value_loss         | 8.85e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8400     |
# |    time_elapsed       | 994      |
# |    total_timesteps    | 672000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.585    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8399     |
# |    policy_loss        | -0.00331 |
# |    value_loss         | 4.56e-05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 675       |
# |    iterations         | 8500      |
# |    time_elapsed       | 1006      |
# |    total_timesteps    | 680000    |
# | train/                |           |
# |    entropy_loss       | -2.89     |
# |    explained_variance | 0.56      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -0.000653 |
# |    value_loss         | 1.97e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8600     |
# |    time_elapsed       | 1017     |
# |    total_timesteps    | 688000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.828    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.00851 |
# |    value_loss         | 8.04e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8700     |
# |    time_elapsed       | 1029     |
# |    total_timesteps    | 696000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.286    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | -0.0312  |
# |    value_loss         | 0.00128  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8800     |
# |    time_elapsed       | 1041     |
# |    total_timesteps    | 704000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.847    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8799     |
# |    policy_loss        | -0.0167  |
# |    value_loss         | 0.000198 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 8900     |
# |    time_elapsed       | 1053     |
# |    total_timesteps    | 712000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.761    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8899     |
# |    policy_loss        | -0.00231 |
# |    value_loss         | 0.000176 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 675      |
# |    iterations         | 9000     |
# |    time_elapsed       | 1065     |
# |    total_timesteps    | 720000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.131    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.0342  |
# |    value_loss         | 0.000655 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 9100     |
# |    time_elapsed       | 1076     |
# |    total_timesteps    | 728000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.217    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9099     |
# |    policy_loss        | -0.0765  |
# |    value_loss         | 0.00522  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 9200     |
# |    time_elapsed       | 1088     |
# |    total_timesteps    | 736000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.0556   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9199     |
# |    policy_loss        | 0.0747   |
# |    value_loss         | 0.0246   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 676      |
# |    iterations         | 9300     |
# |    time_elapsed       | 1100     |
# |    total_timesteps    | 744000   |
# | train/                |          |
# ...
# |    fps                | 617      |
# |    iterations         | 122000   |
# |    time_elapsed       | 15797    |
# |    total_timesteps    | 9760000  |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 121999   |
# |    policy_loss        | 0.214    |
# |    value_loss         | 0.413    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122100   |
# |    time_elapsed       | 15812    |
# |    total_timesteps    | 9768000  |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122099   |
# |    policy_loss        | -0.0751  |
# |    value_loss         | 0.195    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122200   |
# |    time_elapsed       | 15828    |
# |    total_timesteps    | 9776000  |
# | train/                |          |
# |    entropy_loss       | -0.751   |
# |    explained_variance | 0.948    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122199   |
# |    policy_loss        | 0.199    |
# |    value_loss         | 0.454    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122300   |
# |    time_elapsed       | 15843    |
# |    total_timesteps    | 9784000  |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122299   |
# |    policy_loss        | -0.0691  |
# |    value_loss         | 0.408    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122400   |
# |    time_elapsed       | 15859    |
# |    total_timesteps    | 9792000  |
# | train/                |          |
# |    entropy_loss       | -0.71    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122399   |
# |    policy_loss        | -0.0571  |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122500   |
# |    time_elapsed       | 15875    |
# |    total_timesteps    | 9800000  |
# | train/                |          |
# |    entropy_loss       | -0.901   |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122499   |
# |    policy_loss        | -0.0477  |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122600   |
# |    time_elapsed       | 15890    |
# |    total_timesteps    | 9808000  |
# | train/                |          |
# |    entropy_loss       | -0.725   |
# |    explained_variance | 0.964    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122599   |
# |    policy_loss        | 0.013    |
# |    value_loss         | 0.209    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122700   |
# |    time_elapsed       | 15906    |
# |    total_timesteps    | 9816000  |
# | train/                |          |
# |    entropy_loss       | -0.826   |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122699   |
# |    policy_loss        | 0.0585   |
# |    value_loss         | 0.5      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 617      |
# |    iterations         | 122800   |
# |    time_elapsed       | 15921    |
# |    total_timesteps    | 9824000  |
# | train/                |          |
# |    entropy_loss       | -0.483   |
# |    explained_variance | 0.628    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122799   |
# |    policy_loss        | 0.00152  |
# |    value_loss         | 1.1      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 122900   |
# |    time_elapsed       | 15937    |
# |    total_timesteps    | 9832000  |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.941    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122899   |
# |    policy_loss        | -0.0597  |
# |    value_loss         | 1.05     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123000   |
# |    time_elapsed       | 15952    |
# |    total_timesteps    | 9840000  |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 122999   |
# |    policy_loss        | -0.00367 |
# |    value_loss         | 0.0651   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123100   |
# |    time_elapsed       | 15968    |
# |    total_timesteps    | 9848000  |
# | train/                |          |
# |    entropy_loss       | -0.691   |
# |    explained_variance | 0.866    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123099   |
# |    policy_loss        | -0.091   |
# |    value_loss         | 2.4      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123200   |
# |    time_elapsed       | 15983    |
# |    total_timesteps    | 9856000  |
# | train/                |          |
# |    entropy_loss       | -0.766   |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123199   |
# |    policy_loss        | -0.0791  |
# |    value_loss         | 0.117    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123300   |
# |    time_elapsed       | 15998    |
# |    total_timesteps    | 9864000  |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123299   |
# |    policy_loss        | -0.051   |
# |    value_loss         | 0.288    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123400   |
# |    time_elapsed       | 16014    |
# |    total_timesteps    | 9872000  |
# | train/                |          |
# |    entropy_loss       | -0.969   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123399   |
# |    policy_loss        | -0.0812  |
# |    value_loss         | 0.293    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123500   |
# |    time_elapsed       | 16030    |
# |    total_timesteps    | 9880000  |
# | train/                |          |
# |    entropy_loss       | -0.834   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123499   |
# |    policy_loss        | -0.0348  |
# |    value_loss         | 0.322    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123600   |
# |    time_elapsed       | 16045    |
# |    total_timesteps    | 9888000  |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123599   |
# |    policy_loss        | -0.0454  |
# |    value_loss         | 0.153    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123700   |
# |    time_elapsed       | 16061    |
# |    total_timesteps    | 9896000  |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | 0.886    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123699   |
# |    policy_loss        | 0.0318   |
# |    value_loss         | 0.921    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 123800   |
# |    time_elapsed       | 16076    |
# |    total_timesteps    | 9904000  |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123799   |
# |    policy_loss        | 0.0993   |
# |    value_loss         | 0.984    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 123900   |
# |    time_elapsed       | 16092    |
# |    total_timesteps    | 9912000  |
# | train/                |          |
# |    entropy_loss       | -0.536   |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123899   |
# |    policy_loss        | -0.118   |
# |    value_loss         | 0.158    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124000   |
# |    time_elapsed       | 16109    |
# |    total_timesteps    | 9920000  |
# | train/                |          |
# |    entropy_loss       | -0.979   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 123999   |
# |    policy_loss        | -0.00857 |
# |    value_loss         | 0.248    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124100   |
# |    time_elapsed       | 16124    |
# |    total_timesteps    | 9928000  |
# | train/                |          |
# |    entropy_loss       | -0.726   |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124099   |
# |    policy_loss        | -0.0591  |
# |    value_loss         | 0.201    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124200   |
# |    time_elapsed       | 16140    |
# |    total_timesteps    | 9936000  |
# | train/                |          |
# |    entropy_loss       | -0.708   |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124199   |
# |    policy_loss        | -0.075   |
# |    value_loss         | 0.262    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124300   |
# |    time_elapsed       | 16155    |
# |    total_timesteps    | 9944000  |
# | train/                |          |
# |    entropy_loss       | -0.794   |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124299   |
# |    policy_loss        | -0.0946  |
# |    value_loss         | 0.993    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124400   |
# |    time_elapsed       | 16171    |
# |    total_timesteps    | 9952000  |
# | train/                |          |
# |    entropy_loss       | -0.658   |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124399   |
# |    policy_loss        | -0.0513  |
# |    value_loss         | 0.405    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124500   |
# |    time_elapsed       | 16186    |
# |    total_timesteps    | 9960000  |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124499   |
# |    policy_loss        | -0.0175  |
# |    value_loss         | 0.603    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124600   |
# |    time_elapsed       | 16201    |
# |    total_timesteps    | 9968000  |
# | train/                |          |
# |    entropy_loss       | -0.769   |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124599   |
# |    policy_loss        | -0.0268  |
# |    value_loss         | 0.214    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124700   |
# |    time_elapsed       | 16217    |
# |    total_timesteps    | 9976000  |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124699   |
# |    policy_loss        | 0.104    |
# |    value_loss         | 0.369    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 615      |
# |    iterations         | 124800   |
# |    time_elapsed       | 16232    |
# |    total_timesteps    | 9984000  |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124799   |
# |    policy_loss        | 0.0157   |
# |    value_loss         | 0.0649   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 614      |
# |    iterations         | 124900   |
# |    time_elapsed       | 16248    |
# |    total_timesteps    | 9992000  |
# | train/                |          |
# |    entropy_loss       | -1.16    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124899   |
# |    policy_loss        | -0.0632  |
# |    value_loss         | 0.398    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 614      |
# |    iterations         | 125000   |
# |    time_elapsed       | 16263    |
# |    total_timesteps    | 10000000 |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 124999   |
# |    policy_loss        | 0.00845  |
# |    value_loss         | 0.112    |
# ------------------------------------

# %% [markdown]
# # Load A2C Model

# %%
# 加载模型
A2C_model = A2C.load("./RoadRunner/a2c/best_model.zip")

# 设置 coef 为 0 来关闭探索，完全依赖于模型学到的策略
A2C_model.ent_coef = 0.0
A2C_model.vf_coef = 0.0

# %%
A2C_model.policy # 查看 A2C 算法模型架构
# Out:
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=512, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=16, bias=True)
#       (5): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=512, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=16, bias=True)
#       (5): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=3136, out_features=512, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=512, out_features=128, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=128, out_features=16, bias=True)
#       (5): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=16, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=16, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=18, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
A2C_features_extractor = A2C_model.policy.features_extractor
A2C_features_extractor
# Out:
# NatureCNN(
#   (cnn): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#     (6): Flatten(start_dim=1, end_dim=-1)
#   )
#   (linear): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=128, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=128, out_features=16, bias=True)
#     (5): ReLU()
#   )
# )

# %%
A2C_MlpExtractor = A2C_model.policy.mlp_extractor
A2C_MlpExtractor
# Out:
# MlpExtractor(
#   (policy_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): Tanh()
#   )
#   (value_net): Sequential(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): Tanh()
#   )
# )

# %%
A2C_ActionNet = A2C_model.policy.action_net
A2C_ValueNet = A2C_model.policy.value_net

# %%
A2C_ActionNet
# Out:
# Linear(in_features=64, out_features=18, bias=True)

# %%
A2C_ValueNet
# Out:
# Linear(in_features=64, out_features=1, bias=True)

# %% [markdown]
# # 输出每个状态下 16维特征 & 所有动作对应的Logits

# %%
def output_features_logits(obs):

  obs = torch.tensor(obs, dtype=torch.float32, device=device)

  features = A2C_features_extractor(obs)

  policy_values = A2C_MlpExtractor.policy_net(features)

  action_logits = A2C_ActionNet(policy_values)

  return features, action_logits

# %%
# 假设你的输入是一个形状为 (4, 84, 84) 的图像
input_tensor = torch.randn(1, 4, 84, 84).to(device)  # Batch size 1, 输入图像 (4, 84, 84)

features, action_logits = output_features_logits(input_tensor)

print(features)

print(action_logits)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14292\3246032145.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   obs = torch.tensor(obs, dtype=torch.float32, device=device)
# tensor([[0.1610, 0.0000, 0.9939, 1.1447, 0.7310, 0.0687, 3.2791, 4.7115, 0.0000,
#          0.7207, 0.7615, 0.0000, 0.0000, 1.4792, 0.0000, 0.0000]],
#        device='cuda:0', grad_fn=<ReluBackward0>)
# tensor([[ 0.7663, -1.0143,  7.2394, -2.2351,  1.1471, -3.9389, -2.2020,  6.0694,
#          -2.7426, -2.2996,  0.3810, -1.8409, -0.9493, -1.5327, -0.7143, -0.7938,
#          -1.8613, -1.2513]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Collect Episode Data

# %%
n_envs = 1
RoadRunner_env = DummyVecEnv([make_RoadRunner_env for _ in range(n_envs)])  # 用DummyVecEnv包装环境，使其并行
RoadRunner_env = VecTransposeImage(RoadRunner_env) # 转换成 (C, H, W) 而不是 (H, W, C)
RoadRunner_env = VecFrameStack(RoadRunner_env, n_stack=4)  # 堆叠帧，4帧堆叠

# %%
# 确保输出目录存在
output_dir = "./RoadRunner/a2c/evaluation"
os.makedirs(output_dir, exist_ok=True)

num_episodes = 1000

# 为每个 episode 准备记录列表
episode_records = []
action_logits_records = []

# 列名生成，假设每个特征的列名为 f"feature_{i}"，其中 i 为特征编号
def generate_column_names(dimension):
    names = [f"feature_{i+1}" for i in range(dimension)]
    names.append("action")
    names.append("reward")
    return names

for ep in range(1, num_episodes + 1):
    obs = RoadRunner_env.reset()
    done = False

    # 清空记录列表
    episode_records.clear()
    action_logits_records.clear()

    while not done:
        # 提取状态的 特征值 和 动作值
        features, action_logits = output_features_logits(obs)

        features = features.squeeze(0).cpu().detach().numpy()
        action_logits = action_logits.squeeze(0).cpu().detach().numpy()

        # 使用A2C的 predict 方法来选择动作
        action, _states = A2C_model.predict(obs, deterministic=True)  # 选择最大 logits 值的动作

        next_obs, reward, done, info = RoadRunner_env.step(action)

        action_array = np.array([action])  # 将 action 转换为 NumPy 数组
        reward_array = np.array([reward])  # 将 reward 转换为 NumPy 数组

        # 确保 reward 和 action 也是一维数组
        action_array = action_array.flatten()
        reward_array = reward_array.flatten()

        # 合并所有数据到一起，确保它们是一个一维数组
        record = np.concatenate([features, action_array, reward_array])

        episode_records.append(record)
        action_logits_records.append(action_logits)

        obs = next_obs

    # 使用文件路径保存数据
    file_path = os.path.join(output_dir, f"episode_{ep}.csv")
    action_logits_file_path = os.path.join(output_dir, f"episode_{ep}_action_logits.txt")

    # 根据特征的维度生成列名
    column_names = generate_column_names(features.shape[0])  # 使用特征维度自动生成列名

    # 将数据转换为 DataFrame
    df = pd.DataFrame(episode_records, columns=column_names)

    # 保存为 CSV 文件
    df.to_csv(file_path, index=False)

    # 保存 action_logits 到 txt 文件
    with open(action_logits_file_path, 'a') as f:
        for action_logits in action_logits_records:
            action_logits_str = ",".join(map(str, action_logits.flatten()))  # 展平 action_probs 并将其转换为字符串
            f.write(f"{action_logits_str}\n")

    # 清空记录列表以备下一个 episode 使用
    episode_records.clear()
    action_logits_records.clear()

# %% [markdown]
# # Merge Episode

# %%
dim_16 = "./RoadRunner/a2c/evaluation"

def extract_episode_data(dim_dir, feature_dim, output_file):
    """
    提取每个 episode 的数据，并将结果存储到 CSV 文件
    Args:
        dim_dir (str): 目录路径
        feature_dim (int): 每个状态的特征维度（64, 36, 16）
        output_file (str): 最终合并结果保存的文件路径
    """
    episodes = []  # 存储每个 episode 数据

    # 如果文件已经存在，跳过
    if os.path.exists(output_file):
        print(f"{output_file} already exists. Skipping extraction.")
        return

    # 遍历目录中的每个 episode 文件
    for episode_file in os.listdir(dim_dir):
        if episode_file.endswith(".csv"):
            episode_name = episode_file.replace(".csv", "")  # 获取 episode 的基名
            action_logits_file = episode_name + "_action_logits.txt"  # 期望的 action_logits 文件名

            episode_path = os.path.join(dim_dir, episode_file)
            action_logits_path = os.path.join(dim_dir, action_logits_file)

            # 确保 action_logits 文件存在
            if os.path.exists(action_logits_path):
                # 读取 feature 数据 (states)
                df = pd.read_csv(episode_path)
                states = df[[f"feature_{i}" for i in range(1, feature_dim+1)]].values  # (T, feature_dim)

                # 读取 action_logits 数据
                action_logits = np.loadtxt(action_logits_path, delimiter=",")  # (T, n_actions)

                if action_logits.ndim == 1:
                    action_logits = action_logits.reshape(1, -1)  # 一行

                # 获取 max-action_logits 或者其他指定动作的 action_logits 值
                max_action_logits = np.max(action_logits, axis=1)  # 选择每个 state 的 max action_logits 值

                # 获取 max-action_logits 对应的 action (action_logits 的下标)
                actions = np.argmax(action_logits, axis=1)  # 每个 action_logits 对应的动作索引

                # 合并 states 和 max-action_logits 值
                episode_data = np.column_stack((states, max_action_logits, actions))
                episodes.append(episode_data)
            else:
                print(f"Missing action_logits file for {episode_name}, skipping...")

    # 将所有 episode 数据合并到一个 DataFrame 中并保存到文件
    all_episode_data = np.vstack(episodes)  # (T_total, feature_dim+1)
    columns = [f"feature_{i}" for i in range(1, feature_dim+1)] + ["max_action_logits", "action"]
    episode_df = pd.DataFrame(all_episode_data, columns=columns)
    episode_df.to_csv(output_file, index=False)
    print(f"Data extracted and saved to {output_file}")

# 逐个处理目录的数据
extract_episode_data(dim_16, 16, "./RoadRunner/a2c/eval_data.csv")
# Out:
# ./RoadRunner/a2c/eval_data.csv already exists. Skipping extraction.

# %% [markdown]
# # Compute SHAP

# %%
# Step 1: Load and prepare the data
data = pd.read_csv('./RoadRunner/a2c/eval_data.csv')

X = data.drop(columns=['max_action_logits', 'action']).values
Y = data['max_action_logits'].values
Z = data['action'].values

X_tensor = torch.tensor(X, dtype=torch.float32).to(device)
X_tensor[0]
# Out:
# tensor([  80.9117,    0.0000,    0.0000,  414.5998, 2241.8059,    0.0000,
#          364.1568,    0.0000,    0.0000,  891.8977,    0.0000,    0.0000,
#            0.0000, 1564.5344,    0.0000,   71.5301], device='cuda:0')

# %%
len(X_tensor)
# Out:
# 298466

# %%
class ActionLogitFromFeatures(nn.Module):
    def __init__(self, mlp_extractor, action_net):
        super().__init__()
        self.policy_net = mlp_extractor.policy_net
        self.action_net = action_net

    def forward(self, state_features):
        x = self.policy_net(state_features)
        logits = self.action_net(x)
        return logits

# %%
A2C_PolicyActor = ActionLogitFromFeatures(A2C_MlpExtractor, A2C_ActionNet)
A2C_PolicyActor(X_tensor[0])
# Out:
# tensor([-0.6741, -1.2841, -4.6921, -4.9546,  5.5826, -1.3354, -4.6551,  4.5748,
#         -3.6585,  7.9492, -1.0652, -1.1103,  0.0735, -0.9096, -1.0583, -0.2068,
#         -1.3997,  1.2199], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
background_size = int(len(X_tensor) * 0.01)  # Choose 1% of the data
background_data = X_tensor[:background_size]


# print(background_size)
# print(background_data.shape)

explainer = shap.DeepExplainer(A2C_PolicyActor, background_data)
shap_values = explainer.shap_values(X_tensor, check_additivity=False)

# %%
# 拿出各个维度
n_samples, n_features, n_actions = shap_values.shape
feature_names = data.drop(['max_action_logits','action'], axis=1).columns.tolist()

# 每个样本 j 的最大 action 索引
actions = Z.astype(int)           # shape = (n_samples,)
sample_idx = np.arange(n_samples) # [0,1,2,…,n_samples-1]

# fancy‐indexing：对每个样本 j，取 shap_arr[j, :, actions[j]] → (n_features,)
# 结果 shape = (n_samples, n_features)
shap_max = shap_values[sample_idx, :, actions]

# 构造输出 DataFrame
shap_df = pd.DataFrame(shap_max, columns=feature_names)
shap_df['max_action_logits'] = Y
shap_df['action']            = Z

# 保存到 CSV
out_path = './RoadRunner/a2c/shap_data.csv'
shap_df.to_csv(out_path, index=False)
print(f"[+] 已保存：{out_path}")
# Out:
# [+] 已保存：./RoadRunner/a2c/shap_data.csv

# %%
shap_data = pd.read_csv('./RoadRunner/a2c/shap_data.csv').drop(columns=['max_action_logits', 'action']).values
feature_names = pd.read_csv('./RoadRunner/a2c/shap_data.csv').drop(['max_action_logits','action'], axis=1).columns.tolist()

# %%
# 存储Shapley值到原始状态的映射
shapley_to_state_mapping = {}

# 遍历所有的样本，存储每个状态的 Shapley 向量与原始状态的映射
for i in range(len(X_tensor)):
    state = X[i]  # 获取原始状态 (假设你使用的是Tensor)
    shapley_vector = shap_data[i]  # 获取对应的Shapley值向量

    # 将Shapley向量和原始状态的映射保存在字典中
    shapley_to_state_mapping[tuple(shapley_vector)] = state

with open('./RoadRunner/a2c/shapley_to_state_mapping.pkl', 'wb') as f:
    pickle.dump(shapley_to_state_mapping, f)

print("Shapley向量到原始状态的映射已保存。")
# Out:
# Shapley向量到原始状态的映射已保存。

# %%
plt.figure(figsize=(10,10))
shap.summary_plot(shap_data, X, feature_names=feature_names)

# %%
plt.figure(figsize=(10,10))
shap.summary_plot(shap_data, X, feature_names=feature_names, plot_type="bar")

# %%
shap_data[0]
# Out:
# array([ 2.35002823e-02,  5.41436598e-02, -1.22150278e-03, -3.57637376e-01,
#         1.03504682e+00,  8.79424810e-03, -6.72090333e-04,  1.30140913e+00,
#        -2.90122669e-04, -9.18588758e-01,  6.07492961e-03,  1.00648999e-01,
#         3.60908546e-02,  2.43226743e+00,  4.67479974e-03, -1.01507783e+00])

# %%
print(shapley_to_state_mapping.get(tuple(shap_data[0])))
# Out:
# [  80.91173553    0.            0.          414.59976196 2241.8059082
#     0.          364.15682983    0.            0.          891.89770508
#     0.            0.            0.         1564.53442383    0.
#    71.53011322]

# %% [markdown]
# # Action K-Means Clustering

# %%
n_actions = RoadRunner_env.action_space.n

kmeans = KMeans(n_clusters=n_actions)  # 根据动作数选择聚类数量
kmeans.fit(shap_data)
# Out:
# KMeans(n_clusters=np.int64(18))

# %%
# 获取每个样本的聚类标签
labels = kmeans.labels_

# 获取聚类中心
centroids = kmeans.cluster_centers_

print(f"Cluster Labels: {labels}")
print(f"Cluster Centroids: {centroids}")
# Out:
# Cluster Labels: [ 9 13 13 ...  0  0  0]
# Cluster Centroids: [[-4.13391376e-02  1.26037668e-02 -9.89730462e-03  1.66063013e-02
#    2.47529957e-01 -3.87786242e-03  8.21015344e-01  6.83384853e-02
#   -8.92316420e-05 -6.40012875e-02  5.89081499e-04  1.52747472e-02
#    1.19529654e-02  6.84729600e-02 -1.56612159e-03  2.37379039e-01]
#  [ 4.77532549e-02  7.27132860e-02  1.74125316e-03  1.09267096e-01
#    1.62813967e+00  1.28698750e-01  2.28524665e-01  7.69633236e+00
#   -1.57452385e-04  4.30287928e-01  6.43720362e-02  3.06740001e-01
#    4.37336780e-01  1.79446536e-01 -3.54852928e-03 -6.76874853e-01]
#  [ 1.76595125e-01  9.52060130e-02  1.26570657e-02  1.86018241e-02
#   -1.10639706e+00 -6.40564647e-04  2.73237353e-01  1.61501862e+00
#   -2.21176295e-04 -9.18015489e-01 -1.11887527e-02  1.19019643e-01
#    7.69707521e-02  1.46808455e-01 -2.02316883e-02 -8.83422024e-01]
#  [-1.45022678e-01 -2.68305191e-02  3.35025213e-04  3.72599255e-02
#    5.83499345e-01  2.03378157e-02  1.99955682e-01  1.03512844e+00
#   -1.41710259e-04  1.87692359e-01  5.01859313e-03 -3.32443203e-01
#    7.89184712e-02 -1.42099024e-01 -1.75519894e-02  1.29622556e+00]
#  [-1.89257189e-03  1.96776284e-02 -7.90092807e-04  5.57304160e-02
#    1.05369411e+00 -8.70085207e-04  2.60127827e-01  1.08648378e+00
#   -9.07397101e-05  1.67338591e-01  6.23222071e-03  2.37745539e-02
#    2.69559827e-02  4.93480208e-01  1.29085408e-02  4.74578431e-01]
#  [ 2.25033676e-02  9.27053150e-01  3.90048378e-04  3.64954621e-02
#    9.02740765e-01  2.98286528e-03  2.82353976e-01  9.88453743e-01
#    5.91786760e-03  1.43362946e+00  5.16563138e-03 -1.62790337e-01
#    2.25988174e+00  1.06941347e+00 -2.33491304e-02  1.67527925e+00]
#  [-3.96804543e-02  1.27210832e-02  2.37261649e-03  1.47004235e-02
#    5.03526918e-02  1.50712116e-02  3.38817299e-01  5.01299068e+00
#   -5.74291194e-05  1.18025556e-01  7.71255861e-03 -1.20610462e-02
#    1.68704315e-01 -1.80706787e-02  2.05033147e-02 -1.29411611e-01]
#  [-1.84969050e-02  1.49254294e-02  4.33858498e-03  1.18696299e-02
#   -6.03982568e-01  4.79703995e-02  2.30448933e-01  6.24311745e+00
#    2.30161943e-05 -3.29965671e-01  3.44594795e-03 -3.12968892e-02
#    1.46972364e-01 -5.30003138e-02 -8.98812872e-02 -1.81975107e+00]
#  [-2.49478803e-02  4.75797840e-03  4.21755174e-03  9.03349552e-03
#   -1.38061356e+00  1.06291101e-01  2.19972870e-01  8.94282931e+00
#    1.30268819e-04 -1.28861078e-01  8.64586726e-03  1.30026883e-01
#    1.51560668e-01 -6.54583765e-02 -3.60992973e-01 -3.37126273e+00]
#  [ 7.55763883e-02  1.05164854e-01 -1.01182756e-03  5.04146102e-02
#    6.00879435e-01  2.11120608e-04  3.12474779e-01  1.90229451e+00
#   -6.38916402e-04 -1.46825090e-01  7.96801676e-03  1.58560707e-01
#    1.18980510e-01  3.28568954e-01 -1.21829229e-02 -1.05126378e+00]
#  [-4.93370767e-02  9.96253514e-02 -1.49917492e-03  2.71343906e-02
#    1.59972965e+00 -1.42475947e-02  1.90792693e-01 -3.02496045e+00
#   -1.80380210e-04  1.43293491e-01  3.86027824e-03 -2.07855532e-01
#    1.50088143e-01  6.95711594e-01 -1.13974134e-02  1.89856797e+00]
#  [-5.00668740e-01  4.87231093e-01 -1.59491909e-03  1.02925134e-02
#    1.15935709e+00 -2.31252610e-02 -2.65735755e-02  2.50611042e-01
#    5.23867386e-05  9.50254511e-01  2.61412825e-03 -2.27226122e+00
#    8.96036104e-01 -5.48191351e-01 -1.59187156e-02  3.29468725e+00]
#  [ 3.70779019e-02  7.03447225e-02 -1.06091859e-03  5.31477693e-02
#    6.23923332e-01 -1.08204857e-02  3.78597247e-01  1.98337235e+00
#   -2.67853112e-04  2.74158813e-01  8.99331193e-03  9.77582844e-02
#    8.71101026e-02 -1.65807530e-02  1.38125578e-02  1.45885124e-01]
#  [ 5.38278295e-02  4.72006140e-02 -8.78987464e-04  2.26991798e-02
#    6.17336489e-01  7.46431557e-03  2.94398257e-01 -8.50970618e-01
#   -1.65673533e-04  6.65200928e-02  7.37215569e-03 -6.21184679e-02
#    8.19533486e-02  2.90596239e-01 -1.69750408e-02  1.21409041e+00]
#  [ 1.21748982e-01  1.47136675e-01 -1.55265528e-03  5.32096102e-02
#   -4.14254152e-01 -2.71337682e-03  3.79998577e-01  2.83313076e+00
#   -8.09740435e-04  8.09204955e-01  1.16857544e-02  1.62295069e-01
#    1.27869982e-01 -4.70502800e-01  5.06005427e-05 -8.79439175e-01]
#  [-5.73833915e-02  1.00543751e-01 -1.29661546e-03  3.38773800e-02
#   -6.86134188e-02 -4.93954081e-03  3.36191953e-01  2.10724804e+00
#   -4.94176691e-04  9.39542369e-02  6.91865117e-03  8.69258530e-02
#    1.11282235e-01 -6.34928258e-01  1.31292459e-02  1.13266764e-01]
#  [ 1.12075410e-01  1.41273002e-01 -1.75465128e-03  2.65330232e-02
#   -2.03512738e+00  6.90053061e-03  3.19828148e-01  2.62090392e+00
#   -3.66844991e-04  6.29616574e-01  7.94074348e-03  1.44939229e-01
#    1.18353768e-01 -6.08976320e-01 -2.84371720e-02 -1.01658049e+00]
#  [-4.91181330e-02  1.56530936e-02  1.84821970e-03  1.31529195e-03
#    4.08863007e-01  5.81475295e-03  3.78598106e-01  3.71260106e+00
#   -9.14695663e-05  1.55622169e-01  1.15937874e-02 -1.40328548e-02
#    1.88981543e-01 -2.69066813e-03 -3.28903657e-03  4.08396010e-01]]

# %% [markdown]
# # Boundary Points Identification

# %%
def find_boundary_points(shap_values, n_clusters):

    boundary_points = []

    for i in range(n_clusters):
        for j in range(i + 1, n_clusters):
            # 计算每个样本到质心 i 和质心 j 的距离
            dist_to_centroids = cdist(shap_values, [centroids[i], centroids[j]], 'euclidean')
                
            # 找到距离差最小的样本，即边界点
            dist_diff = np.abs(dist_to_centroids[:, 0] - dist_to_centroids[:, 1])
            boundary_index = np.argmin(dist_diff)
                
            # 获取边界点
            boundary_point = shap_values[boundary_index]
            boundary_points.append((boundary_point, (i, j)))  # 存储边界点和对应的簇对

    # 返回所有的边界点和它们的簇对
    return boundary_points

# %% [markdown]
# # DNN approximates RL's behavior to qurey Boundary's actions

# %%
df = pd.read_csv("./RoadRunner/a2c/eval_data.csv")
scaler = StandardScaler()

# 提取输入特征和标签
X = df[[f"feature_{i}" for i in range(1, 17)]].values.astype(np.float32)
X = scaler.fit_transform(X)   # 每列特征 (feature1~feature16) 独立标准化到均值0、方差1

y = df["action"].values.astype(np.int64)

# %%
class FeatureDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = FeatureDataset(X, y)

train_loader = DataLoader(dataset, batch_size=512, shuffle=True)

# %%
class DNN(nn.Module):
    def __init__(self, input_dim=16, output_dim=18):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, output_dim)
        )

    def forward(self, x):
        return self.net(x)

# 自动确定输出类别数
DNN_model = DNN().to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(DNN_model.parameters(), lr=1e-3)

# %%
num_epochs = 100
train_losses = []

for epoch in range(num_epochs):
    DNN_model.train()
    total_loss = 0.0

    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        preds = DNN_model(X_batch)
        loss = criterion(preds, y_batch)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_losses.append(total_loss)
    print(f"Epoch [{epoch+1}/{num_epochs}]  Training Loss: {total_loss:.4f}")
# Out:
# Epoch [1/100]  Training Loss: 122.5872
# Epoch [2/100]  Training Loss: 38.0360
# Epoch [3/100]  Training Loss: 31.6311
# Epoch [4/100]  Training Loss: 28.4954
# Epoch [5/100]  Training Loss: 26.8152
# Epoch [6/100]  Training Loss: 25.4019
# Epoch [7/100]  Training Loss: 23.9846
# Epoch [8/100]  Training Loss: 22.2742
# Epoch [9/100]  Training Loss: 21.3367
# Epoch [10/100]  Training Loss: 20.3709
# Epoch [11/100]  Training Loss: 19.6617
# Epoch [12/100]  Training Loss: 18.9647
# Epoch [13/100]  Training Loss: 18.0893
# Epoch [14/100]  Training Loss: 17.1629
# Epoch [15/100]  Training Loss: 15.9386
# Epoch [16/100]  Training Loss: 15.8775
# Epoch [17/100]  Training Loss: 15.0933
# Epoch [18/100]  Training Loss: 14.5915
# Epoch [19/100]  Training Loss: 14.0427
# Epoch [20/100]  Training Loss: 13.7953
# Epoch [21/100]  Training Loss: 13.3346
# Epoch [22/100]  Training Loss: 12.3603
# Epoch [23/100]  Training Loss: 12.0673
# Epoch [24/100]  Training Loss: 11.7121
# Epoch [25/100]  Training Loss: 11.9223
# Epoch [26/100]  Training Loss: 10.5731
# Epoch [27/100]  Training Loss: 10.3332
# Epoch [28/100]  Training Loss: 10.1840
# Epoch [29/100]  Training Loss: 10.4449
# Epoch [30/100]  Training Loss: 9.5517
# Epoch [31/100]  Training Loss: 9.6287
# Epoch [32/100]  Training Loss: 8.6424
# Epoch [33/100]  Training Loss: 8.3284
# Epoch [34/100]  Training Loss: 8.4055
# Epoch [35/100]  Training Loss: 7.5694
# Epoch [36/100]  Training Loss: 7.8750
# Epoch [37/100]  Training Loss: 7.8928
# Epoch [38/100]  Training Loss: 8.3706
# Epoch [39/100]  Training Loss: 7.2030
# Epoch [40/100]  Training Loss: 6.4252
# Epoch [41/100]  Training Loss: 7.4172
# Epoch [42/100]  Training Loss: 6.8051
# Epoch [43/100]  Training Loss: 6.9945
# Epoch [44/100]  Training Loss: 6.1586
# Epoch [45/100]  Training Loss: 6.4980
# Epoch [46/100]  Training Loss: 6.5282
# Epoch [47/100]  Training Loss: 5.5366
# Epoch [48/100]  Training Loss: 6.0613
# Epoch [49/100]  Training Loss: 5.6632
# Epoch [50/100]  Training Loss: 5.3548
# Epoch [51/100]  Training Loss: 5.7612
# Epoch [52/100]  Training Loss: 5.5923
# Epoch [53/100]  Training Loss: 5.3997
# Epoch [54/100]  Training Loss: 5.3103
# Epoch [55/100]  Training Loss: 4.6587
# Epoch [56/100]  Training Loss: 4.5795
# Epoch [57/100]  Training Loss: 4.4471
# Epoch [58/100]  Training Loss: 4.7518
# Epoch [59/100]  Training Loss: 5.1703
# Epoch [60/100]  Training Loss: 3.8572
# Epoch [61/100]  Training Loss: 4.9446
# Epoch [62/100]  Training Loss: 3.7593
# Epoch [63/100]  Training Loss: 4.2652
# Epoch [64/100]  Training Loss: 4.2512
# Epoch [65/100]  Training Loss: 5.0108
# Epoch [66/100]  Training Loss: 3.6411
# Epoch [67/100]  Training Loss: 4.5944
# Epoch [68/100]  Training Loss: 3.8273
# Epoch [69/100]  Training Loss: 3.4769
# Epoch [70/100]  Training Loss: 4.3199
# Epoch [71/100]  Training Loss: 4.1436
# Epoch [72/100]  Training Loss: 3.6418
# Epoch [73/100]  Training Loss: 3.5664
# Epoch [74/100]  Training Loss: 2.9801
# Epoch [75/100]  Training Loss: 3.2884
# Epoch [76/100]  Training Loss: 4.2707
# Epoch [77/100]  Training Loss: 3.3603
# Epoch [78/100]  Training Loss: 3.2324
# Epoch [79/100]  Training Loss: 3.5045
# Epoch [80/100]  Training Loss: 3.0381
# Epoch [81/100]  Training Loss: 2.9313
# Epoch [82/100]  Training Loss: 3.4690
# Epoch [83/100]  Training Loss: 3.3508
# Epoch [84/100]  Training Loss: 2.8280
# Epoch [85/100]  Training Loss: 3.1322
# Epoch [86/100]  Training Loss: 2.9907
# Epoch [87/100]  Training Loss: 3.1998
# Epoch [88/100]  Training Loss: 2.8077
# Epoch [89/100]  Training Loss: 3.0529
# Epoch [90/100]  Training Loss: 3.3851
# Epoch [91/100]  Training Loss: 1.9654
# Epoch [92/100]  Training Loss: 3.2694
# Epoch [93/100]  Training Loss: 2.3297
# Epoch [94/100]  Training Loss: 2.8162
# Epoch [95/100]  Training Loss: 3.3268
# Epoch [96/100]  Training Loss: 2.2148
# Epoch [97/100]  Training Loss: 2.9851
# Epoch [98/100]  Training Loss: 2.3705
# Epoch [99/100]  Training Loss: 2.6039
# Epoch [100/100]  Training Loss: 3.4847

# %%
with torch.no_grad():
    sample_input = torch.tensor(X[0], dtype=torch.float32, device=device)
    sample_input = sample_input.unsqueeze(0)

    logits = DNN_model(sample_input)
    probs = torch.softmax(logits, dim=1) 
    action_label = torch.argmax(probs, dim=1).item()

print("Predicted action:", action_label)
# Out:
# Predicted action: 9

# %%
torch.save(DNN_model.state_dict(), "RoadRunner_A2C_DNN_.pth")
print("✅ Model saved as RoadRunner_A2C_DNN_.pth")
# Out:
# ✅ Model saved as RoadRunner_A2C_DNN_.pth

# %% [markdown]
# # Inverse Shapley Values

# %%
# 调用函数寻找边界点
# 'shapley_vectors' 是已计算出的 SHAP 向量数据
boundary_points = find_boundary_points(shap_data, n_clusters=18)

# 创建一个列表来存储所有边界点的数据
# 每个元素将是一个包含 SHAP 向量和对应簇的编号的列表
boundary_data = []

# 创建一个列表来存储所有Inverse SHAP后的边界点的数据
shap_inverse_boundary_data = []

# 遍历每个边界点
for boundary_point, clusters in boundary_points:
    # 这里的 boundary_point 是一个 SHAP 向量，包含该边界点的所有特征
    # clusters 是一个元组，包含两个簇的编号 (cluster_1, cluster_2)

    i, j = clusters  # 两个簇编号

    # # 判断离哪个簇心更近，作为最终动作标签
    # dist_i = np.linalg.norm(boundary_point - centroids[i])
    # dist_j = np.linalg.norm(boundary_point - centroids[j])

    # if dist_i < dist_j:
    #     action_label = i
    # else:
    #     action_label = j

    # Inverse Shapley: 映射回原始状态
    shap_inverse_boundary_point = shapley_to_state_mapping.get(tuple(boundary_point))

    # print(shap_inverse_boundary_point)

    # ---------------- RL-Guided Labeling 核心部分 ----------------
    shap_inverse_boundary_point_scaled = scaler.transform(np.array(shap_inverse_boundary_point).reshape(1, -1))

    shap_inverse_boundary_point_tensor = torch.tensor(shap_inverse_boundary_point_scaled, dtype=torch.float32, device=device)

    with torch.no_grad():
        logits = DNN_model(shap_inverse_boundary_point_tensor)
        probs = torch.softmax(logits, dim=1) 
        action_label = torch.argmax(probs, dim=1).item()

    # 保存 SHAP 向量 + 簇编号 + 标签
    boundary_data.append(list(boundary_point) + [i, j, action_label])
    # 保存状态空间的边界点数据
    shap_inverse_boundary_data.append(list(shap_inverse_boundary_point) + [i, j, action_label])

# 计算每个边界点的特征列数
# 假设每个 SHAP 向量有 16 个特征
num_features = len(boundary_data[0]) - 3  # 减去 Cluster_1, Cluster_2, Action_Label

# 创建列名：Feature_1, Feature_2, ..., Feature_16 和 Cluster_1, Cluster_2, Action_Label
columns = [f"Feature_{k+1}" for k in range(num_features)] + ['Cluster_1', 'Cluster_2', 'Action_Label']

# 将边界点数据转换为 pandas DataFrame
boundary_df = pd.DataFrame(boundary_data, columns=columns)
shap_inverse_boundary_df = pd.DataFrame(shap_inverse_boundary_data, columns=columns)

# 保存 DataFrame 到 CSV 文件
boundary_df.to_csv('./RoadRunner/a2c/boundary_points.csv', index=False)
shap_inverse_boundary_df.to_csv('./RoadRunner/a2c/shap_inverse_boundary_points.csv', index=False)

# %%
bd_data = pd.read_csv('./RoadRunner/a2c/shap_inverse_boundary_points.csv')

# 提取特征（16个特征）
bd_X = bd_data.iloc[:, :-3].values  # 假设前16列是特征

# 提取标签
bd_Y = bd_data['Action_Label'].values

# %%
bd_X[0]
# Out:
# array([ 161.50502014,    0.        ,    0.        ,    0.        ,
#         849.9095459 ,    0.        ,    0.        , 1037.38525391,
#           0.        ,  440.89178467,    0.        ,    0.        ,
#           0.        ,  270.63540649,   56.4806633 ,  786.63555908])

# %%
bd_Y[0]
# Out:
# np.int64(7)

# %% [markdown]
# # Decision Boundary Regression using Decision Tree

# %%
# 创建决策树分类器
bd_DecisionTree = DecisionTreeClassifier(random_state=0)

# 训练模型
bd_DecisionTree.fit(bd_X, bd_Y)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
# 手动指定列名
feature_names = [f'Feature_{i+1}' for i in range(bd_X.shape[1])]
coefficient_names = [f'x{i+1}' for i in range(bd_X.shape[1])]

class_names = [str(i) for i in np.unique(bd_Y)]

# %%
# Plot Decision Tree 
plt.figure(figsize=(80, 40))
plot_tree(bd_DecisionTree, feature_names=feature_names, class_names=class_names, filled=True, impurity = False) # 柔和蓝绿色调)
plt.title(r"RoadRunner A2C Decision Tree", fontsize=60)
plt.savefig("./RoadRunner/a2c/RoadRunner_a2c_decision_tree.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Decision Boundary Regression using Linear Regression

# %%
bd_LinearRegression = LinearRegression()

bd_LinearRegression.fit(bd_X, bd_Y)
# Out:
# LinearRegression()

# %%
# 封装函数：四舍五入 + 裁剪
def round_and_clip(predictions, min_value=0, max_value=8):
    # 四舍五入并裁剪到指定范围
    predictions_int = np.rint(predictions).astype(int)
    return np.clip(predictions_int, min_value, max_value)

# %%
def display_linear_formula(lr, feature_names, F_name='f1', tol=1e-16):
    """
    打印并返回线性打分公式：
      - 跳过 |coef| < tol 的特征
      - 正数前用 '+', 负数前用 '−'
    """
    coefs = lr.coef_.ravel()
    intercept = float(lr.intercept_)
    
    terms = []
    for w, name in zip(coefs, feature_names):
        # 忽略纯 0 或接近 0 的系数
        if abs(w) < tol:
            continue
        sign = "+" if w > 0 else "−"
        terms.append(f"{sign} {abs(w):.2e}·{name}")
    
    # 如果没有任何非零项，就只显示 intercept
    if not terms:
        formula = f"{F_name}(x) = {intercept:.2e}"
    else:
        formula = f"{F_name}(x) = {intercept:.2e} " + " ".join(terms)
    
    return formula

# %%
display_linear_formula(bd_LinearRegression, coefficient_names, F_name="f")
# Out:
# 'f(x) = 8.82e+00 − 9.00e-04·x1 − 5.92e-03·x2 + 1.77e-03·x3 − 9.55e-03·x4 − 6.94e-04·x5 − 4.30e-03·x6 + 1.03e-04·x7 − 9.70e-04·x8 + 1.42e-02·x9 − 1.03e-03·x10 − 4.23e-03·x11 − 2.10e-03·x12 − 1.02e-04·x13 − 4.19e-04·x14 + 1.34e-03·x15 + 1.08e-03·x16'

# %% [markdown]
# # Decision Boundary Regression using Logistic Regression

# %%
bd_LogisticRegression = LogisticRegression(random_state=0, max_iter=10000, solver='saga', multi_class='multinomial')

bd_LogisticRegression.fit(bd_X, bd_Y)
# Out:
# c:\Users\Administrator\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1264: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(max_iter=10000, multi_class='multinomial', random_state=0,
#                    solver='saga')

# %%
def display_logistic_regression_formulas(lr, feature_names, action_names, model_name='f'):
    """
    给定 Logistic Regression 模型，输出每个动作（类别）对应的公式
    公式形式: f1(x) = intercept + Σ w_i * x_i
    """
    coefs = lr.coef_  # shape = (n_classes, n_features)
    intercepts = lr.intercept_  # shape = (n_classes,)
    
    for k, action_name in enumerate(action_names):
        terms = []
        for i, name in enumerate(feature_names):
            if coefs[k, i] >= 0:
                terms.append(f"+ {coefs[k, i]:.2e}·{name}")
            else:
                terms.append(f"− {abs(coefs[k, i]):.2e}·{name}")
        # 格式化公式
        formula = f"{model_name}_{action_name}(x) = {intercepts[k]:.2e} " + " ".join(terms)
        print(formula)

# %%
display_logistic_regression_formulas(bd_LogisticRegression, coefficient_names, class_names)
# Out:
# f_2(x) = -2.86e-06 − 1.35e-03·x1 + 1.61e-03·x2 − 1.98e-05·x3 + 1.56e-03·x4 − 1.17e-02·x5 + 3.76e-03·x6 − 6.08e-04·x7 + 1.83e-02·x8 − 3.67e-06·x9 − 1.45e-03·x10 + 2.28e-03·x11 + 8.55e-03·x12 + 6.14e-03·x13 − 2.22e-03·x14 − 2.16e-03·x15 − 8.77e-03·x16
# f_4(x) = -5.35e-05 + 3.34e-03·x1 − 1.96e-03·x2 − 6.08e-04·x3 − 6.50e-05·x4 + 4.06e-03·x5 − 1.04e-03·x6 + 2.62e-03·x7 − 5.72e-03·x8 − 7.24e-06·x9 + 3.40e-03·x10 − 3.75e-05·x11 − 4.91e-03·x12 − 2.44e-03·x13 − 6.74e-03·x14 − 1.03e-03·x15 + 3.41e-03·x16
# f_5(x) = -2.82e-05 − 7.23e-03·x1 + 1.14e-02·x2 − 1.97e-05·x3 − 1.84e-05·x4 − 6.60e-03·x5 − 1.41e-03·x6 − 6.26e-03·x7 − 8.87e-03·x8 + 2.14e-05·x9 − 7.41e-03·x10 − 5.33e-05·x11 − 3.18e-03·x12 + 7.26e-03·x13 + 1.81e-03·x14 + 2.15e-03·x15 + 3.50e-03·x16
# f_7(x) = -1.50e-04 − 2.88e-03·x1 + 2.75e-03·x2 − 7.10e-04·x3 − 1.06e-03·x4 + 1.15e-02·x5 + 1.82e-03·x6 + 8.55e-03·x7 + 1.14e-02·x8 − 4.94e-05·x9 + 6.46e-03·x10 − 1.96e-03·x11 + 1.15e-02·x12 + 1.57e-03·x13 − 3.53e-03·x14 + 1.96e-03·x15 − 7.76e-03·x16
# f_9(x) = 2.34e-04 + 8.11e-03·x1 − 1.38e-02·x2 + 1.36e-03·x3 − 4.17e-04·x4 + 2.76e-03·x5 − 3.13e-03·x6 − 4.31e-03·x7 − 1.51e-02·x8 + 3.89e-05·x9 − 9.97e-04·x10 − 2.26e-04·x11 − 1.20e-02·x12 − 1.25e-02·x13 + 1.07e-02·x14 − 9.17e-04·x15 + 9.62e-03·x16

# %% [markdown]
# # Performance Evaluation

# %%
# 创建环境和执行episode的函数
def RL_run_episode(env, num_episodes, model):

    rewards = []

    for ep in range(num_episodes):
        obs = env.reset() 
        done = False
        total = 0

        while not done:
            action, _states = model.predict(obs, deterministic=True) 
            next_obs, reward, done, info = env.step(action)

            total += reward
            obs = next_obs       

        rewards.append(total)

    return rewards

def ML_run_episode(env, num_episodes, model):

    rewards = []

    for ep in range(num_episodes):
        obs = env.reset() 
        done = False
        total = 0

        while not done:
            # 提取状态的 特征值 和 动作值
            features, action_logits = output_features_logits(obs)

            features = features.squeeze(0).cpu().detach().numpy()
            action_logits = action_logits.squeeze(0).cpu().detach().numpy()

            action = model.predict([features]) 

            if isinstance(model, LinearRegression):
                action = round_and_clip(action)

            # print(action)

            next_obs, reward, done, info = env.step(action)

            total += reward
            obs = next_obs
        rewards.append(total)        

    return rewards

# %% [markdown]
# ### A2C

# %%
A2C_result = RL_run_episode(RoadRunner_env, 100, A2C_model) 

print(A2C_result)
print(sum(A2C_result))
# Out:
# [array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([79.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([87.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([84.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([83.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([83.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([73.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([79.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([71.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([70.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([74.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([82.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([51.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([51.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([86.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([72.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([72.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([73.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32)]
# [2528.]

# %%
A2C_result_np = np.array(A2C_result)
np.save("./RoadRunner/A2C_result.npy", A2C_result_np)

# %% [markdown]
# ### Decision Tree

# %%
DT_result = ML_run_episode(RoadRunner_env, 130, bd_DecisionTree)

print(DT_result)
print(sum(DT_result))
# Out:
# [array([14.], dtype=float32), array([55.], dtype=float32), array([0.], dtype=float32), array([27.], dtype=float32), array([8.], dtype=float32), array([27.], dtype=float32), array([18.], dtype=float32), array([37.], dtype=float32), array([0.], dtype=float32), array([19.], dtype=float32), array([37.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([12.], dtype=float32), array([13.], dtype=float32), array([21.], dtype=float32), array([65.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([27.], dtype=float32), array([8.], dtype=float32), array([27.], dtype=float32), array([81.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([49.], dtype=float32), array([22.], dtype=float32), array([0.], dtype=float32), array([16.], dtype=float32), array([8.], dtype=float32), array([2.], dtype=float32), array([12.], dtype=float32), array([13.], dtype=float32), array([21.], dtype=float32), array([31.], dtype=float32), array([8.], dtype=float32), array([22.], dtype=float32), array([81.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([61.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([55.], dtype=float32), array([21.], dtype=float32), array([0.], dtype=float32), array([79.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([79.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([30.], dtype=float32), array([32.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([54.], dtype=float32), array([5.], dtype=float32), array([6.], dtype=float32), array([72.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([66.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([49.], dtype=float32), array([22.], dtype=float32), array([0.], dtype=float32), array([66.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([31.], dtype=float32), array([8.], dtype=float32), array([22.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([66.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([61.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([81.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([49.], dtype=float32), array([22.], dtype=float32), array([0.], dtype=float32), array([50.], dtype=float32), array([22.], dtype=float32), array([0.], dtype=float32), array([48.], dtype=float32), array([8.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([50.], dtype=float32), array([22.], dtype=float32), array([0.], dtype=float32), array([54.], dtype=float32), array([5.], dtype=float32), array([6.], dtype=float32), array([31.], dtype=float32), array([8.], dtype=float32), array([22.], dtype=float32), array([31.], dtype=float32), array([8.], dtype=float32), array([22.], dtype=float32), array([61.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([12.], dtype=float32), array([13.], dtype=float32), array([21.], dtype=float32), array([22.], dtype=float32), array([6.], dtype=float32), array([25.], dtype=float32), array([55.], dtype=float32), array([11.], dtype=float32), array([0.], dtype=float32), array([72.], dtype=float32)]
# [2848.]

# %%
DT_result_np = np.array(DT_result)
np.save("./RoadRunner/A2C_DT_result.npy", DT_result_np)

# %% [markdown]
# ### Linear Regression

# %%
LinearRegression_result = ML_run_episode(RoadRunner_env, 100, bd_LinearRegression)

print(LinearRegression_result)
print(sum(LinearRegression_result))

# %%
LinearRegression_result_np = np.array(LinearRegression_result)
np.save("./RoadRunner/A2C_LinearRegression_result.npy", LinearRegression_result_np)

# %% [markdown]
# ### Logistic Regression

# %%
LogisticRegression_result = ML_run_episode(RoadRunner_env, 106, bd_LogisticRegression)

print(LogisticRegression_result)
print(sum(LogisticRegression_result))
# Out:
# [array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([74.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([73.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([85.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([67.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([64.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([81.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([67.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([80.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([63.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([89.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([65.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([70.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([65.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([88.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([85.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([70.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([77.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([75.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([69.], dtype=float32), array([0.], dtype=float32)]
# [2565.]

# %%
LogisticRegression_result_np = np.array(LogisticRegression_result)
np.save("./RoadRunner/A2C_LogisticRegression_result.npy", LogisticRegression_result_np)

# %% [markdown]
# # Fidelity Score Computation

# %%
num_episodes = 100

Decision_Tree_Fidelity = []
Linear_Regression_Fidelity = []
Logistic_Regression_Fidelity = []

for ep in range(num_episodes):
    obs = RoadRunner_env.reset() 
    done = False

    Decision_Tree_Count = 0
    Linear_Regression_Count = 0
    Logistic_Regression_Count = 0

    epoch = 0 

    while not done:
        action, _states = A2C_model.predict(obs, deterministic=True) 

        features, action_logits = output_features_logits(obs)
        features = features.squeeze(0).cpu().detach().numpy()

        Decision_Tree_action = bd_DecisionTree.predict([features]) 
        Linear_Regression_action = round_and_clip(bd_LinearRegression.predict([features]))
        Logistic_Regression_action = bd_LogisticRegression.predict([features])

        if Decision_Tree_action == action:
            Decision_Tree_Count += 1

        if Linear_Regression_action == action:
            Linear_Regression_Count += 1

        if Logistic_Regression_action == action:
            Logistic_Regression_Count += 1
        
        next_obs, reward, done, info = RoadRunner_env.step(action)

        obs = next_obs       
        epoch += 1

    Decision_Tree_Fidelity.append(Decision_Tree_Count/epoch)
    Linear_Regression_Fidelity.append(Linear_Regression_Count/epoch)
    Logistic_Regression_Fidelity.append(Logistic_Regression_Count/epoch)

# %%
Average_RoadRunner_A2C_Decision_Tree_Fidelity = sum(Decision_Tree_Fidelity)/len(Decision_Tree_Fidelity)

# %%
Average_RoadRunner_A2C_Linear_Regression_Fidelity = sum(Linear_Regression_Fidelity)/len(Linear_Regression_Fidelity)

# %%
Average_RoadRunner_A2C_Logistic_Regression_Fidelity = sum(Logistic_Regression_Fidelity)/len(Logistic_Regression_Fidelity)

# %%
results = {
    "Model": ["Decision Tree", "Linear Regression", "Logistic Regression"],
    "Average Fidelity": [
        Average_RoadRunner_A2C_Decision_Tree_Fidelity,
        Average_RoadRunner_A2C_Linear_Regression_Fidelity,
        Average_RoadRunner_A2C_Logistic_Regression_Fidelity
    ]
}

# 2️⃣ 转为 DataFrame
df = pd.DataFrame(results)

# 3️⃣ 保存到 CSV 文件（便于之后统一导入绘图）
df.to_csv("RoadRunner_A2C_Fidelity.csv", index=False)

print("✅ Fidelity results saved to RoadRunner_A2C_Fidelity.csv")
# Out:
# ✅ Fidelity results saved to RoadRunner_A2C_Fidelity.csv
